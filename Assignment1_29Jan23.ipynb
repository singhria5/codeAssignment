# %%
Assignment 1 - 29th Jan Python Assignment
By Shriza singh

Solutions 

Q1-
Solution -Python was created by Guido van Rossum, and first released on February 20, 1991.


Q2- 
Solution -Object Oriented programming and structured programming are supported by Python.


Q3-
Solution- Yes,Python is case sensitive while dealing with identifiers.


Q4-
Solution- The extensions for Python files are - . py  



Q5-
Solution- The python program is first compiled and then interpreted.


Q6-
Solution- The following are blocks: a module, a function body, and a class definition used to define in python language.


Q7-
Solution- Hash character(#)  is used to give single line comment in Python .


Q8-
Solution- The function sys.version can help us to find the version of python that we are currently working 




Q9-
Solution- Python supports making anonymous functions at runtime using construct called "lambda" .


Q10-
Solution- In python,PIP is Preferred Installer Program .


Q11-
Solution- Some in built functions in python are print() , type() , input() , sorted() , max() 


Q12-
Solution- Maximum length of identifier in Python is 79 characters.


Q13-
Solution- Benefits of using python:
1)Simple to use and understand.
2)Free and open source.
3)Dynamically typed.
4)Portability .
5)Supportive community.
6)Extensive library.




Q14-
Solution- In order to manage memory, Python uses a private heap that houses all of its objects and data structures. The Python memory manager is responsible for internal administration of this private heap.




Q15-
Solution- Steps to install Python:
You can add the full path to python.exe by:


The Properties menu can be accessed by right-clicking This PC.


selecting the Advanced system settings option from the left menu.


selecting the Environment Variables button, which is located in the bottom right.


Selecting the Path variable and clicking Edit in the System variables section. All of the directories that are currently included in the PATH variable will be displayed on the following screen.


by selecting New and choosing the Python installation location.


Now, Python can be used straight from the command line without needing to provide its location. Try using python —version to find out what version of Python is currently installed on your machine.


Q16-
Solution- The spaces at the start of a code line are known as indentation. Python's indentation is crucial, unlike other programming languages where it just serves to make the code easier to understand. A block of code is indicated via indentation in Python.
